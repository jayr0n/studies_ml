# %%
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784', as_frame=False, parser='auto')

# %%
mnist.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
print(mnist.DESCR)
# Out:
# **Author**: Yann LeCun, Corinna Cortes, Christopher J.C. Burges
# **Source**: [MNIST Website](http://yann.lecun.com/exdb/mnist/) - Date unknown
# **Please cite**:
#
# The MNIST database of handwritten digits with 784 features, raw data available at: http://yann.lecun.com/exdb/mnist/. It can be split in a training set of the first 60,000 examples, and a test set of 10,000 examples
#
# ...

# %%
X, y = mnist['data'], mnist['target']

# %%
X.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %% [markdown]
# # plotting the algarism

# %%
import matplotlib.pyplot as plt

def plot_digit(image_data):
    image = image_data.reshape(28, 28)
    plt.imshow(image, cmap="binary")
    plt.axis("off")

some_digit = X[0]
plot_digit(some_digit)
plt.show()

# %%
plt.figure(figsize=(9, 9))
for idx, image_data in enumerate(X[:100]):
    plt.subplot(10, 10, idx + 1)
    plot_digit(image_data)
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
import numpy as np

y = y.astype(np.uint8)

# %% [markdown]
# ## Setting training data

# %%
X_train, X_test, y_train, y_test = X[:60000], X[60000:], y[:60000], y[60000:]

# %% [markdown]
# # Training binary classfier

# %%
y_train_5 = (y_train == 5)

# %%
y_test_5 = (y_test == 5)

# %%
from sklearn.linear_model import SGDClassifier

# sgd_clf = SGDClassifier(random_state=42)
# sgd_clf.fit(X_train, y_train_5)

# sgd_clf.predict([some_digit])

# %%
import joblib 
sgd_clf = joblib.load("sgd_clf.pkl")

# %% [markdown]
# # Performance Measures

# %% [markdown]
# ## Measuring Accuracy Using Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cross_val_score(sgd_clf, X_train, y_train_5, cv=3, scoring="accuracy")
# Out:
# array([0.95035, 0.96035, 0.9604 ])

# %%
from sklearn.base import BaseEstimator

class Never5Classifier(BaseEstimator):
    def fit(self, X, y=None):
        pass
    def predict(self, X):
        return np.zeros((len(X), 1), dtype=bool)

# %%
never_5_clf = Never5Classifier()

cross_val_score(never_5_clf, X_train, y_train_5, cv=3, scoring="accuracy")
# Out:
# array([0.91125, 0.90855, 0.90915])

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier()
dummy_clf.fit(X_train, y_train_5)
print(any(dummy_clf.predict(X_train)))
# Out:
# False

# %%
cross_val_score(dummy_clf, X_train, y_train_5, cv=3, scoring="accuracy")
# Out:
# array([0.90965, 0.90965, 0.90965])

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.model_selection import cross_val_predict

y_train_pred = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_train_5, y_train_pred)
cm
# Out:
# array([[53892,   687],
#        [ 1891,  3530]], dtype=int64)

# %%
y_train_perfect_predictions = y_train_5

# %%
confusion_matrix(y_train_5, y_train_perfect_predictions)
# Out:
# array([[54579,     0],
#        [    0,  5421]], dtype=int64)

# %% [markdown]
# # Precision and recall

# %%
from sklearn.metrics import precision_score, recall_score

# %% [markdown]
# <h2>Precision: $\frac{TP}{TP+FP}$ </h2>

# %%
precision_score(y_train_5, y_train_pred) # 3530 / (3530 + 687)
# Out:
# 0.8370879772350012

# %% [markdown]
# <h2>Recall: $\frac{TP}{TP+FN}$ </h2>

# %%
recall_score(y_train_5, y_train_pred) # 3530 / (3530 + 1891)
# Out:
# 0.6511713705958311

# %% [markdown]
# <h2>F1: ${2 *}\frac{Precision * Recall}{Precision + Recall}$ </h2>

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_train_5, y_train_pred)
# Out:
# 0.7325171197343846

# %% [markdown]
# # Trade-off precison/recall

# %%
y_scores = sgd_clf.decision_function([some_digit])
y_scores
# Out:
# array([2164.22030239])

# %%
threshold = 0

y_some_digit_pred = (y_scores > threshold)

y_some_digit_pred
# Out:
# array([ True])

# %%
threshold = 3000

y_some_digit_pred = (y_scores > threshold)

y_some_digit_pred
# Out:
# array([False])

# %%
#y_scores = cross_val_predict(sgd_clf, X_train, y_train_5, cv=3, method="decision_function")

# %%
import joblib 

#joblib.dump(y_scores, 'y_scores.pkl')

y_scores = joblib.load("y_scores.pkl")

# %%
y_scores
# Out:
# array([  1200.93051237, -26883.79202424, -33072.03475406, ...,
#         13272.12718981,  -7258.47203373, -16877.50840447])

# %%
y_scores
# Out:
# array([  1200.93051237, -26883.79202424, -33072.03475406, ...,
#         13272.12718981,  -7258.47203373, -16877.50840447])

# %% [markdown]
# ## calculating recall and precision

# %%
from sklearn.metrics import precision_recall_curve

precisions, recalls, thresholds = precision_recall_curve(y_train_5, y_scores)

# %%
precisions
# Out:
# array([0.09035   , 0.09035151, 0.09035301, ..., 1.        , 1.        ,
#        1.        ])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot(thresholds, precisions[:-1], "b--", label="Precision", linewidth=2)
plt.plot(thresholds, recalls[:-1], "g-", label="Recall", linewidth=2)
plt.vlines(threshold, 0, 1.0, "k", "dotted", label="threshold")

idx = (thresholds >= threshold).argmax() 
plt.plot(thresholds[idx], precisions[idx], "bo")
plt.plot(thresholds[idx], recalls[idx], "go")
plt.axis([-50000, 50000, 0, 1])
plt.grid()
plt.xlabel("Threshold")
plt.legend(loc="center right")

plt.show()

# %%
import matplotlib.patches as patches  

plt.figure(figsize=(6, 5)) 

plt.plot(recalls, precisions, linewidth=1.67, label="Precision/Recall curve")
plt.plot([recalls[idx], recalls[idx]], [0, precisions[idx]], "k:")
plt.plot([0.0, recalls[idx]], [precisions[idx], precisions[idx]], "k:")
plt.plot([recalls[idx]], [precisions[idx]], "ko",
         label="Point at threshold 3,000")

plt.gca().add_patch(patches.FancyArrowPatch(
    (0.79, 0.60), (0.61, 0.78),
    connectionstyle="arc3,rad=.2",
    arrowstyle="Simple, tail_width=1.5, head_width=8, head_length=10",
    color="#444444"))

plt.text(0.56, 0.62, "Higher\nthreshold", color="#333333")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.axis([0, 1, 0, 1])
plt.grid()
plt.legend(loc="lower right")

plt.show()

# %%
idx_for_90_precision = (precisions >= 0.90).argmax()
threshold_for_90_precision = thresholds[idx_for_90_precision]
threshold_for_90_precision
# Out:
# 3370.0194991439557

# %%
y_train_pred_90 = (y_scores >= threshold_for_90_precision)

# %%
precision_score(y_train_5, y_train_pred_90)
# Out:
# 0.9000345901072293

# %%
recall_at_90_precision = recall_score(y_train_5, y_train_pred_90)
recall_at_90_precision
# Out:
# 0.4799852425751706

# %% [markdown]
# # ROC curve

# %%
from sklearn.metrics import roc_curve

# %%
fpr, tpr, thresholds = roc_curve(y_train_5, y_scores)

# %%
idx_for_threshold_at_90 = (thresholds <= threshold_for_90_precision).argmax()
tpr_90, fpr_90 = tpr[idx_for_threshold_at_90], fpr[idx_for_threshold_at_90]

plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, linewidth=2, label="ROC curve")
plt.plot([0, 1], [0, 1], 'k:', label="Random classifier's ROC curve")
plt.plot([fpr_90], [tpr_90], "ko", label="Threshold for 90% precision")

# extra code – just beautifies and saves Figure 3–7
plt.gca().add_patch(patches.FancyArrowPatch(
    (0.20, 0.89), (0.07, 0.70),
    connectionstyle="arc3,rad=.4",
    arrowstyle="Simple, tail_width=1.5, head_width=8, head_length=10",
    color="#444444"))
plt.text(0.12, 0.71, "Higher\nthreshold", color="#333333")
plt.xlabel('False Positive Rate (Fall-Out)')
plt.ylabel('True Positive Rate (Recall)')
plt.grid()
plt.axis([0, 1, 0, 1])
plt.legend(loc="lower right", fontsize=13)

plt.show()

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_train_5, y_scores)
# Out:
# 0.9604938554008616

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest_clf = RandomForestClassifier(random_state=42)

# %%
y_probas_forest = cross_val_predict(forest_clf, X_train, y_train_5, cv=3, method='predict_proba')

# %%
import joblib 

#joblib.dump(y_probas_forest, 'y_probas_forest.pkl')

y_probas_forest = joblib.load("y_probas_forest.pkl")

# %%
y_probas_forest
# Out:
# array([[0.11, 0.89],
#        [0.99, 0.01],
#        [0.96, 0.04],
#        ...,
#        [0.02, 0.98],
#        [0.92, 0.08],
#        [0.94, 0.06]])

# %%
y_scores_forest = y_probas_forest[:, 1]

# %%
fpr_forest, tpr_forest, thresholds_forest = roc_curve(y_train_5, y_scores_forest)

# %%
plt.figure(figsize=(8, 5))
plt.axis([0, 1, 0, 1])

plt.plot(fpr, tpr, 'k--', label="SGD",)
plt.plot(fpr_forest, tpr_forest, label="Random Forest", linewidth=2)
plt.plot([0, 1], [0, 1], 'k:', label="Random Forest's ROC curve")

plt.legend(loc="lower right", fontsize=13)
plt.show()

# %%
roc_auc_score(y_train_5, y_scores_forest)
# Out:
# 0.9983436731328145

# %%
y_train_pred_forest = y_probas_forest[:, 1] >= 0.5
f1_score(y_train_5, y_train_pred_forest)
# Out:
# 0.9274509803921569

# %%
precision_score(y_train_5, y_train_pred_forest)
# Out:
# 0.9897468089558485

# %%
recall_score(y_train_5, y_train_pred_forest)
# Out:
# 0.8725327430363402

# %% [markdown]
# # Multiclass classfier

# %%
from sklearn.svm import SVC
import joblib

#svm_clf = SVC()

#svm_clf.fit(X_train, y_train)

svm_clf = joblib.load("svm_clf.pkl")
svm_clf.predict([some_digit])
# Out:
# array([5], dtype=uint8)

# %% [markdown]
# ### In the backstage Scikit-Learn used the OvO(One versus One) strategy, training 45 binary classfiers

# %%
some_digit_scores = svm_clf.decision_function([some_digit])

# %%
tuple(zip(svm_clf.classes_, some_digit_scores[0]))
# Out:
# ((0, 1.7250197664732896),
#  (1, 2.7280908822885768),
#  (2, 7.2510017991420455),
#  (3, 8.307637896172595),
#  (4, -0.31087254321792546),
#  (5, 9.313248199189204),
#  (6, 1.7097510328947647),
#  (7, 2.7676520238948132),
#  (8, 6.230495365837555),
#  (9, 4.84771047760298))

# %%
from sklearn.multiclass import OneVsRestClassifier

# %%
#ovr_clf = OneVsRestClassifier(SVC())

#ovr_clf.fit(X_train, y_train)

import joblib

#joblib.dump(ovr_clf, 'ovr_clf.pkl')

ovr_clf = joblib.load("ovr_clf.pkl")
#svm_clf.predict([some_digit])

# %%
ovr_clf.predict([some_digit])
# Out:
# array([5], dtype=uint8)

# %% [markdown]
# ## Using SGD

# %% [markdown]
# ### In this case Scikit-learn dont need to run OvR or OvO, because SGD, RandomForest and Naive Bayes can handler with different classes by default

# %%
#sgd_clf.fit(X_train, y_train)

import joblib

#joblib.dump(sgd_clf, 'sgd_clf_full.pkl')

sgd_clf_full = joblib.load("sgd_clf_full.pkl")

# %%
sgd_clf_full.predict([some_digit])
# Out:
# array([3], dtype=uint8)

# %% [markdown]
# ### the model predict 3(wrong) the right answer should be 5

# %%
sgd_clf_full.decision_function([some_digit])
# Out:
# array([[-31893.03095419, -34419.69069632,  -9530.63950739,
#           1823.73154031, -22320.14822878,  -1385.80478895,
#         -26188.91070951, -16147.51323997,  -4604.35491274,
#         -12050.767298  ]])

# %%
cross_val_score(sgd_clf_full, X_train, y_train, cv=3, scoring='accuracy')
# Out:
# array([0.87365, 0.85835, 0.8689 ])

# %% [markdown]
# ### Using scaler as pre preprocessing to improve accuracy

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train.astype(np.float64))

# %%
#cross_val_score(sgd_clf_full, X_train_scaled, y_train, cv=3, scoring='accuracy')

# %%
# cross_val_score array : ([0.8983, 0.891 , 0.9018])

# %% [markdown]
# # Error analisys

# %%
#y_train_pred = cross_val_predict(sgd_clf_full, X_train_scaled, y_train, cv=3)

# %%
import joblib 

#joblib.dump(y_train_pred, 'y_train_pred.pkl')

y_train_pred = joblib.load('y_train_pred.pkl')

# %%
conf_matrix = confusion_matrix(y_train, y_train_pred)

# %%
conf_matrix
# Out:
# array([[5577,    0,   22,    5,    8,   43,   36,    6,  225,    1],
#        [   0, 6400,   37,   24,    4,   44,    4,    7,  212,   10],
#        [  27,   27, 5220,   92,   73,   27,   67,   36,  378,   11],
#        [  22,   17,  117, 5227,    2,  203,   27,   40,  403,   73],
#        [  12,   14,   41,    9, 5182,   12,   34,   27,  347,  164],
#        [  27,   15,   30,  168,   53, 4444,   75,   14,  535,   60],
#        [  30,   15,   42,    3,   44,   97, 5552,    3,  131,    1],
#        [  21,   10,   51,   30,   49,   12,    3, 5684,  195,  210],
#        [  17,   63,   48,   86,    3,  126,   25,   10, 5429,   44],
#        [  25,   18,   30,   64,  118,   36,    1,  179,  371, 5107]],
#       dtype=int64)

# %%
plt.matshow(conf_matrix, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# ### the 5s are a little bit more gray than the another numbers which means that we have less 5s in dataset or the classification don't handle to good with 5s, or both.

# %% [markdown]
# ## Or you can use a better plot with the same propours

# %%
from sklearn.metrics import ConfusionMatrixDisplay

plt.rc('font', size=9)  # extra code – make the text smaller
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred)
plt.show()

# %%
plt.rc('font', size=10)
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred,
                                        normalize="true", values_format=".0%")
plt.show()

# %%
row_sums = conf_matrix.sum(axis=1, keepdims=True)

# %%
norm_conf_mx = conf_matrix / row_sums

# %%
np.fill_diagonal(norm_conf_mx, 0)

plt.matshow(norm_conf_mx, cmap=plt.cm.gray)
plt.show()

# %% [markdown]
# ### Matrix With Erros the lines(rows) represent real classes and the columns represent the predicted classes

# %% [markdown]
# ### The same plot ofthe above

# %%
sample_weight = (y_train_pred != y_train)
plt.rc('font', size=10)  # extra code
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred,
                                        sample_weight=sample_weight,
                                        normalize="true", values_format=".0%")
plt.show()

# %% [markdown]
# # Comparing CM and CM Normalized

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
plt.rc('font', size=9)
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred, ax=axs[0])
axs[0].set_title("Confusion matrix")
plt.rc('font', size=10)
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred, ax=axs[1],
                                        normalize="true", values_format=".0%")
axs[1].set_title("CM normalized by row")
plt.show()

# %% [markdown]
# # Errors normalized by row x column

# %%
# extra code – this cell generates and saves Figure 3–10
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
plt.rc('font', size=10)
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred, ax=axs[0],
                                        sample_weight=sample_weight,
                                        normalize="true", values_format=".0%")
axs[0].set_title("Errors normalized by row")
ConfusionMatrixDisplay.from_predictions(y_train, y_train_pred, ax=axs[1],
                                        sample_weight=sample_weight,
                                        normalize="pred", values_format=".0%")
axs[1].set_title("Errors normalized by column")
plt.show()
plt.rc('font', size=14)  # make fonts great again

# %%
cl_a, cl_b = 3, 5
X_aa = X_train[(y_train == cl_a) & (y_train_pred == cl_a)] 
X_ab = X_train[(y_train == cl_a) & (y_train_pred == cl_b)] 
X_ba = X_train[(y_train == cl_b) & (y_train_pred == cl_a)]
X_bb = X_train[(y_train == cl_b) & (y_train_pred == cl_b)]

# %%
size = 5
pad = 0.2
plt.figure(figsize=(size, size))
for images, (label_col, label_row) in [(X_ba, (0, 0)), (X_bb, (1, 0)),
                                       (X_aa, (0, 1)), (X_ab, (1, 1))]:
    for idx, image_data in enumerate(images[:size*size]):
        x = idx % size + label_col * (size + pad)
        y = idx // size + label_row * (size + pad)
        plt.imshow(image_data.reshape(28, 28), cmap="binary",
                   extent=(x, x + 1, y, y + 1))
plt.xticks([size / 2, size + pad + size / 2], [str(cl_a), str(cl_b)])
plt.yticks([size / 2, size + pad + size / 2], [str(cl_b), str(cl_a)])
plt.plot([size + pad / 2, size + pad / 2], [0, 2 * size + pad], "k:")
plt.plot([0, 2 * size + pad], [size + pad / 2, size + pad / 2], "k:")
plt.axis([0, 2 * size + pad, 0, 2 * size + pad])
plt.xlabel("Predicted label")
plt.ylabel("True label")
plt.show()

# %% [markdown]
# ### The two 5x5 left blocks show the algarismo classification as 3, and the another 5x5 show algarismo classification as 5

# %% [markdown]
# # Multilabel Classification

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
y_train_large = (y_train >= 7)

# %%
y_train_odd = (y_train % 2 == 1)

# %%
y_multilabel = np.c_[y_train_large, y_train_odd]

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(X_train, y_multilabel)
# Out:
# KNeighborsClassifier()

# %%
knn_clf.predict([some_digit])
# Out:
# array([[False,  True]])

# %%
y_train_knn_pred = cross_val_predict(knn_clf, X_train, y_multilabel, cv=3)

# %%
f1_score(y_multilabel, y_train_knn_pred, average='macro')
# Out:
# 0.976410265560605

# %%
f1_score(y_multilabel, y_train_knn_pred, average="weighted")
# Out:
# 0.9778357403921755

# %% [markdown]
# ### Classifier chains is a machine learning method for problem transformation in multi-label classification. It combines the computational efficiency of the binary relevance method while still being able to take the label dependencies into account for classification. [refer](https://en.wikipedia.org/wiki/Classifier_chains)

# %%
from sklearn.multioutput import ClassifierChain

chain_clf = ClassifierChain(SVC(), cv=3, random_state=42)
chain_clf.fit(X_train[:2000], y_multilabel[:2000])
# Out:
# ClassifierChain(base_estimator=SVC(), cv=3, random_state=42)

# %%
chain_clf.predict([some_digit])
# Out:
# array([[0., 1.]])

# %% [markdown]
# # Multioutput Classification

# %%
noise = np.random.randint(0, 100, (X_train.shape[0], X_train.shape[1]))

# %%
X_train_mod = X_train + noise

# %%
noise = np.random.randint(0, 100, (X_test.shape[0], X_test.shape[1]))

# %%
X_test_mod = X_test + noise

# %%
y_train_mod = X_train

# %%
y_test_mod = X_test

# %% [markdown]
# ## removing noise from digit images

# %%
plt.subplot(121); plot_digit(X_test_mod[0])
plt.subplot(122); plot_digit(y_test_mod[0])
plt.show()

# %%
knn_clf.fit(X_train_mod, y_train_mod)
# Out:
# KNeighborsClassifier()

# %%
clean_digit = knn_clf.predict([X_test_mod[4]])

# %%
plt.subplot(131)
plot_digit(X_test_mod[4])  # with noise
plt.text(0.5, -0.2, 'With Noise', size=10, ha='center', transform=plt.gca().transAxes)

plt.subplot(132)
plot_digit(clean_digit)  # predict
plt.text(0.5, -0.2, 'Predicted', size=10, ha='center', transform=plt.gca().transAxes)

plt.subplot(133)
plot_digit(X_test[4])  # original
plt.text(0.5, -0.2, 'Original', size=10, ha='center', transform=plt.gca().transAxes)

plt.show()
